# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

# %%
image = cv.imread("ba2.jpeg")
image1 = cv.cvtColor(image, cv.COLOR_BGR2RGB) 
# print("image1", image1)
print("image", image)
# Out:
# image [[[188 227 242]
#   [189 228 243]
#   [189 228 243]
#   ...
#   [202 228 244]
#   [202 228 244]
#   [202 228 244]]
#
#  [[186 222 238]
#   [183 222 237]
#   [185 221 237]
#   ...
#   [202 228 244]
#   [202 228 244]
#   [202 228 244]]
#
#  [[190 224 240]
#   [190 226 242]
#   [194 228 244]
#   ...
#   [202 228 244]
#   [202 228 244]
#   [202 228 244]]
#
#  ...
#
#  [[145 160 186]
#   [143 158 184]
#   [141 158 184]
#   ...
#   [176 192 221]
#   [175 191 220]
#   [175 191 220]]
#
#  [[142 157 183]
#   [142 157 183]
#   [141 158 184]
#   ...
#   [173 189 218]
#   [175 191 220]
#   [174 190 219]]
#
#  [[144 159 185]
#   [144 159 185]
#   [143 160 186]
#   ...
#   [173 189 218]
#   [175 191 220]
#   [174 190 219]]]

# %%
pixel = image1.reshape((-1, 3))

# %%
image1.shape, pixel
cluster = 1

# %%
kmeans = KMeans(n_clusters=cluster, n_init="auto", random_state=12)
kmeans.fit(pixel)
# Out:
# KMeans(n_clusters=1, random_state=12)

# %%
dominant_colors = kmeans.cluster_centers_.astype(int)
dominant_colors
# Out:
# array([[178, 160, 140]])

# %%
quantized_pixels = dominant_colors[kmeans.labels_]
quantized_image = quantized_pixels.reshape(image.shape)

# %%
fig, ax = plt.subplots(1,2, figsize=(12, 12))
ax[0].imshow(image1)
ax[0].set_title('Original Image')
ax[0].axis('off')

ax[1].imshow(quantized_image)
ax[1].set_title('Quantized Image')
ax[1].axis('off')
plt.tight_layout()
plt.show()

# %%
def rgb_to_hex(rgb):
    return '#%02x%02x%02x' % tuple(rgb)

plt.figure(figsize=(12, 2))
plt.title("Dominant Color Palette")
for i, color in enumerate(dominant_colors):
    plt.subplot(1, cluster, i + 1)
    palette_square = np.zeros((10, 10, 3), dtype=int) + color
    plt.imshow(palette_square)
    plt.axis('off')
    
    hex_code = rgb_to_hex(color)
    plt.text(5, 12, hex_code, fontsize=8, ha='center', rotation=45)

plt.show()

# %%
final_image = cv.cvtColor(quantized_image.astype("uint8"), cv.COLOR_RGB2BGR )
cv.imwrite('quantized_output.jpg', final_image)
# Out:
# True
